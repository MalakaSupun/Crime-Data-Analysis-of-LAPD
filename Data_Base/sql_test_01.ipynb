# %% [markdown]
# ## Data Analysis...

# %%
# import keras
import tensorflow.keras
# import tensorflow as tf
# # # Avoid OOM errors by setting GPU Memory Consumption Growth
# gpus = tf.config.experimental.list_physical_devices('GPU')
# for gpu in gpus: 
#     tf.config.experimental.set_memory_growth(gpu, True)
# tf.config.list_physical_devices('GPU')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 # import keras
# ----> 2 import tensorflow.keras
#       3 # import tensorflow as tf
#       4 # # # Avoid OOM errors by setting GPU Memory Consumption Growth
#       5 # gpus = tf.config.experimental.list_physical_devices('GPU')
#       6 # for gpu in gpus:
#       7 #     tf.config.experimental.set_memory_growth(gpu, True)
#       8 # tf.config.list_physical_devices('GPU')
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/_tf_keras/keras/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
#       9 from keras.api import callbacks
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/api/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/api/activations/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/src/__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/src/activations/__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import celu
#       4 from keras.src.activations.activations import elu
#       5 from keras.src.activations.activations import exponential
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/src/activations/activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/src/backend/__init__.py:38
#      36 # Import backend functions.
#      37 if backend() == "tensorflow":
# ---> 38     from keras.src.backend.tensorflow import *  # noqa: F403
#      39     from keras.src.backend.tensorflow.core import Variable as BackendVariable
#      40 elif backend() == "jax":
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/src/backend/tensorflow/__init__.py:1
# ----> 1 from keras.src.backend.tensorflow import core
#       2 from keras.src.backend.tensorflow import distribution_lib
#       3 from keras.src.backend.tensorflow import image
#
# File ~/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:12
#      10 from keras.src.backend.common import is_int_dtype
#      11 from keras.src.backend.common import standardize_dtype
# ---> 12 from keras.src.backend.common.backend_utils import slice_along_axis
#      13 from keras.src.backend.common.keras_tensor import KerasTensor
#      14 from keras.src.backend.common.name_scope import name_scope as base_name_scope
#
# ImportError: cannot import name 'slice_along_axis' from 'keras.src.backend.common.backend_utils' (/home/malaka/Projects/Python_Projects/Python_venvs/Image_processing_01/lib/python3.12/site-packages/keras/src/backend/common/backend_utils.py)

# %% [markdown]
# #### Python Libraries ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Load CSV ...

# %%
df = pd.read_csv(r'/home/malaka/Projects/CV_Projects/Crime_Data_Analysis_of_LAPD/Data_sets/Ready_dataset.csv')
df.head()
# Out:
#        DR_NO   Date Rptd    DATE OCC TIME OCC  AREA   AREA NAME  Rpt Dist No  \
# 0  190326475  2020-03-01  2020-03-01    21:30     7    Wilshire          784
# 1  200106753  2020-02-09  2020-02-08    18:00     1     Central          182
# 2  200320258  2020-11-11  2020-11-04    17:00     3   Southwest          356
# 3  200907217  2023-05-10  2020-03-10    20:37     9    Van Nuys          964
# 4  200412582  2020-09-09  2020-09-09    06:30     4  Hollenbeck          413
#
#    Part 1-2  Crm Cd                               Crm Cd Desc  ...  \
# 0         1     510                          VEHICLE - STOLEN  ...
# 1         1     330                     BURGLARY FROM VEHICLE  ...
# 2         1     480                             BIKE - STOLEN  ...
# 3         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...
# 4         1     510                          VEHICLE - STOLEN  ...
#
#   Temperature (°C)  Dew point (°C)  Humidity (%) Precipitation (mm)  \
# 0            15.85        3.600000         44.00           0.000000
# 1            17.20        9.400000         60.00           0.000000
# 2            21.70       11.700000         53.00           0.000000
# 3            18.53       15.078333         80.55           0.461667
# 4            22.20       17.800000         76.00           0.000000
#
#    Wind Direction(degrees°) Windspeed (km/h)  Air pressure (hPa)  \
# 0                245.000000              9.4         1013.700000
# 1                  0.000000              0.0         1017.200000
# 2                  0.000000              0.0         1018.700000
# 3                103.833333              7.6         1015.521667
# 4                  0.000000              0.0         1006.350000
#
#   Sunshine total(min) Wind Gust (km/h) Snow depth(mm)
# 0                 NaN              NaN            NaN
# 1                 NaN              NaN            NaN
# 2                 NaN              NaN            NaN
# 3                 NaN              NaN            NaN
# 4                 NaN              NaN            NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# #### Drop NaN columns ...

# %%
df = df.drop(['Sunshine total(min)',	'Wind Gust (km/h)',	'Snow depth(mm)'], axis=1)
df.sample(5)
# Out:
#             DR_NO   Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  \
# 298799  201716055  2020-12-04  2020-12-04    19:00    17   Devonshire
# 896928  241904743  2024-01-20  2024-01-20    23:45    19      Mission
# 205417  210505553  2021-02-07  2021-01-25    20:00     5       Harbor
# 120528  201314086  2020-07-17  2020-07-16    16:00    13       Newton
# 9611    201206629  2020-02-06  2020-02-06    13:30    12  77th Street
#
#         Rpt Dist No  Part 1-2  Crm Cd  \
# 298799         1761         2     888
# 896928         1921         1     433
# 205417          516         1     761
# 120528         1317         1     510
# 9611           1268         1     341
#
#                                               Crm Cd Desc  ... Month  \
# 298799                                        TRESPASSING  ...    12
# 896928               DRIVING WITHOUT OWNER CONSENT (DWOC)  ...     1
# 205417                                    BRANDISH WEAPON  ...     1
# 120528                                   VEHICLE - STOLEN  ...     7
# 9611    THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     2
#
#                   Date/Time  Temperature (°C) Dew point (°C)  Humidity (%)  \
# 298799  2020-12-04 19:00:00            20.600         -12.10          10.0
# 896928  2024-01-20 23:45:00            14.275          11.35          82.5
# 205417  2021-01-25 20:00:00            12.800          -1.50          37.0
# 120528  2020-07-16 16:00:00            19.400          14.40          73.0
# 9611    2020-02-06 13:30:00             8.900          -0.30          52.5
#
#        Precipitation (mm)  Wind Direction(degrees°) Windspeed (km/h)  \
# 298799              0.000                      0.00              0.0
# 896928              0.325                    108.25              7.6
# 205417              0.000                    270.00             11.2
# 120528              0.000                      0.00              0.0
# 9611                0.000                      0.00              0.0
#
#        Air pressure (hPa) Rainy Day
# 298799            1021.90         0
# 896928            1012.00         1
# 205417            1006.80         0
# 120528            1013.60         0
# 9611              1021.05         0
#
# [5 rows x 39 columns]

# %%
# Example: Rainy days (assuming a certain threshold of precipitation)
df['Rainy Day'] = df['Precipitation (mm)'].apply(lambda x: 1 if x > 0 else 0)
df["Rainy Day"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 989324    0
# 989325    0
# 989326    0
# 989327    0
# 989328    0
# Name: Rainy Day, Length: 989329, dtype: int64
